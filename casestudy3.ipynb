# %% [markdown]
# # case study #3
# A textile company regularly spent money on five advertising companies for their ads data are given

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import colors

df=pd.read_csv('Downloads\Add_sales_data_2018.csv')
print(df)
df.columns
# Out:
#            Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0    2018-10-08              208.00              222.25              206.85
# 1    2018-10-05              217.00              218.60              205.90
# 2    2018-10-04              223.50              227.80              216.15
# 3    2018-10-03              230.00              237.50              225.75
# 4    2018-10-01              234.55              234.60              221.05
# ..          ...                 ...                 ...                 ...
# 200  2017-12-14              288.00              288.25              279.20
# 201  2017-12-13              290.00              292.50              282.20
# 202  2017-12-12              298.60              298.60              286.65
# 203  2017-12-11              290.00              299.55              285.90
# 204  2017-12-08              287.55              289.90              285.05
#
# ...

# %% [markdown]
# # # these are the given data,we need to find out
# A)correlation between profit and advertisement.

# %%
co_matrix=df.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(co_matrix,vmin=-1,vmax=1,annot=True,linewidth=0.5,cmap='YlGnBu')
plt.show()

# %% [markdown]
# # This Correlation matrix shows the strong positive correlation between advertisement and profit.

# %% [markdown]
# # Build a regression model to predict the profit from the given data

# %%
data1=df.drop(['Date'], axis=1)
y=data1['Profit(in Thousands)']
X=data1.drop(['Profit(in Thousands)'], axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=40, test_size=0.25)
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(X_train,y_train)
predictions=model.predict(X_test)
print(y_test)
print(predictions)
# Out:
# 116    5395.217
# 5      4404.686
# 89     4898.776
# 35     4419.421
# 185    5903.253
# 81     5027.633
# 123    5238.366
# 138    5247.011
# 69     5030.451
# 118    5318.100
# 143    5134.657
# 186    5861.830
# 96     4647.356
# 26     4451.999
# 191    5780.799
# 144    5111.806
# 161    5212.949
# 23     4465.950
# 77     5187.445
# 37     4480.363
# 54     4671.113
# 28     4416.136
# 100    5131.898
# 97     4648.834
# 168    5616.791
# 136    4915.682
# 18     4190.965
# 109    5577.150
# 125    5153.977
# 142    5163.322
# 33     4513.600
# 46     4558.651
# 172    5789.791
# 90     4887.296
# 11     4435.571
# 170    5728.804
# 140    5250.150
# 59     5190.814
# 64     5239.060
# 151    5146.949
# 164    4997.719
# 199    5425.371
# 155    5078.636
# 129    5140.372
# 42     4432.864
# 120    5182.368
# 149    5177.610
# 196    5676.934
# 93     4705.198
# 67     5001.615
# 179    6137.800
# 24     4435.174
# Name: Profit(in Thousands), dtype: float64
# ...

# %%
from sklearn.metrics import mean_squared_error
print('MSE is',mean_squared_error(y_test,predictions))
# Out:
# MSE is 3.8177566733216664e-25

# %%
# Out:
# MSE is 3.8177566733216664e-25

# %% [markdown]
# # The Mean Squared Error (MSE) is a measure of how close a fitted line is to data points,he lower the value the better and 0 means the model is perfect.

# %% [markdown]
# # Predict the profit generated by the company, if they wish to spend the
# following amount for advertisement

# %%
df3=pd.read_csv('Desktop\Add_sales_data_2018.csv')
print(df3)
A=df3['Add1(in Thousands)','Add2(in Thousands)','Add3(in Thousands)','Add4(in Thousands)','Add5(in Thousands)']

predictions=model.predict(A_test)

print(predictions)
# Out:
#      Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0                 290.0               312.0               309.0
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 200                 NaN                 NaN                 NaN
# 201                 NaN                 NaN                 NaN
# 202                 NaN                 NaN                 NaN
# 203                 NaN                 NaN                 NaN
# 204                 NaN                 NaN                 NaN
#
#      Add4(in Thousands)  Add5(in Thousands)
# 0                 298.0               320.0
# 1                   NaN                 NaN
# 2                   NaN                 NaN
# ...

# %% [markdown]
# # Build a regression model to predict the profit from the given data

# %%
# Out:
#            Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 15   2018-09-12              216.35              223.70              212.65
# 9    2018-09-24              233.55              239.20              230.75
# 100  2018-05-14              280.00              281.35              251.85
# 132  2018-03-26              258.05              263.50              253.70
# 68   2018-06-27              265.10              268.40              261.20
# 95   2018-05-21              244.10              248.35              240.55
# 159  2018-02-14              287.95              289.00              280.90
# 162  2018-02-08              282.00              286.50              276.10
# 147  2018-03-05              274.80              276.95              270.55
# 182  2018-01-10              315.00              319.10              312.55
# 191  2017-12-28              306.50              309.30              303.55
# ...
